# %%
import pandas as pd
import numpy as np

# %%
black_friday= pd.read_csv(r"C:\Users\GANNOJU SHAHSANK\Downloads\NARESH IT\Black Friday project\train.csv")

# %%
black_friday
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# 3                               2               0                  12
# 4                              4+               0                   8
# ...                           ...             ...                 ...
# 550063                          1               1                  20
# 550064                          3               0                  20
# 550065                         4+               1                  20
# 550066                          2               0                  20
# 550067                         4+               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      NaN                 NaN      8370
# 1                      6.0                14.0     15200
# 2                      NaN                 NaN      1422
# 3                     14.0                 NaN      1057
# 4                      NaN                 NaN      7969
# ...                    ...                 ...       ...
# 550063                 NaN                 NaN       368
# 550064                 NaN                 NaN       371
# 550065                 NaN                 NaN       137
# 550066                 NaN                 NaN       365
# 550067                 NaN                 NaN       490
#
# [550068 rows x 12 columns]

# %%
black_friday.shape
# Out:
# (550068, 12)

# %%
type(black_friday)
# Out:
# pandas.core.frame.DataFrame

# %%
black_friday.head(3)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422

# %%
black_friday.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 50.4+ MB

# %%
black_friday.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
black_friday
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# 3                               2               0                  12
# 4                              4+               0                   8
# ...                           ...             ...                 ...
# 550063                          1               1                  20
# 550064                          3               0                  20
# 550065                         4+               1                  20
# 550066                          2               0                  20
# 550067                         4+               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      NaN                 NaN      8370
# 1                      6.0                14.0     15200
# 2                      NaN                 NaN      1422
# 3                     14.0                 NaN      1057
# 4                      NaN                 NaN      7969
# ...                    ...                 ...       ...
# 550063                 NaN                 NaN       368
# 550064                 NaN                 NaN       371
# 550065                 NaN                 NaN       137
# 550066                 NaN                 NaN       365
# 550067                 NaN                 NaN       490
#
# [550068 rows x 12 columns]

# %%
print(type(np.nan))
# Out:
# <class 'float'>

# %%
df= black_friday

# %%
df = df.fillna(0) # or method='ffill' for forward filling

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
df['Product_Category_3'].head()
# Out:
# 0     0.0
# 1    14.0
# 2     0.0
# 3     0.0
# 4     0.0
# Name: Product_Category_3, dtype: float64

# %%
df = df.fillna(method = 'backfill') #backward filling
# Out:
# C:\Users\GANNOJU SHAHSANK\AppData\Local\Temp\ipykernel_6852\4031495884.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method = 'backfill') #backward filling

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
df1 = df.copy()

# %%
df1.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
df1.loc[:,'Age'].head()  #loc if we want to give column name ( Label-based LOCator )
# Out:
# 0    0-17
# 1    0-17
# 2    0-17
# 3    0-17
# 4     55+
# Name: Age, dtype: object

# %%
df1.iloc[:,3].head()       # Index-based LOCator
# Out:
# 0    0-17
# 1    0-17
# 2    0-17
# 3    0-17
# 4     55+
# Name: Age, dtype: object

# %%
df1.iloc[0:4,0:3]
# Out:
#    User_ID Product_ID Gender
# 0  1000001  P00069042      F
# 1  1000001  P00248942      F
# 2  1000001  P00087842      F
# 3  1000001  P00085442      F

# %%
df1[2:5]
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 2                 0.0                 0.0      1422
# 3                14.0                 0.0      1057
# 4                 0.0                 0.0      7969

# %%
df1.iloc[:,0:2]
# Out:
#         User_ID Product_ID
# 0       1000001  P00069042
# 1       1000001  P00248942
# 2       1000001  P00087842
# 3       1000001  P00085442
# 4       1000002  P00285442
# ...         ...        ...
# 550063  1006033  P00372445
# 550064  1006035  P00375436
# 550065  1006036  P00375436
# 550066  1006038  P00375436
# 550067  1006039  P00371644
#
# [550068 rows x 2 columns]

# %%
#select first row of dataframe

df1.iloc[0]
# Out:
# User_ID                         1000001
# Product_ID                    P00069042
# Gender                                F
# Age                                0-17
# Occupation                           10
# City_Category                         A
# Stay_In_Current_City_Years            2
# Marital_Status                        0
# Product_Category_1                    3
# Product_Category_2                  0.0
# Product_Category_3                  0.0
# Purchase                           8370
# Name: 0, dtype: object

# %%
#select last row of dataframe

df1.iloc[-1]
# Out:
# User_ID                         1006039
# Product_ID                    P00371644
# Gender                                F
# Age                               46-50
# Occupation                            0
# City_Category                         B
# Stay_In_Current_City_Years           4+
# Marital_Status                        1
# Product_Category_1                   20
# Product_Category_2                  0.0
# Product_Category_3                  0.0
# Purchase                            490
# Name: 550067, dtype: object

# %%
#Select second last column of dataframe
df1.iloc[:,-2]
# Out:
# 0          0.0
# 1         14.0
# 2          0.0
# 3          0.0
# 4          0.0
#           ...
# 550063     0.0
# 550064     0.0
# 550065     0.0
# 550066     0.0
# 550067     0.0
# Name: Product_Category_3, Length: 550068, dtype: float64

# %%
#select 1st, 5th and 10th rows with 1st, 4th and 7th columns
df1.iloc[[0,4,9], [0,3,6]]
# Out:
#    User_ID    Age Stay_In_Current_City_Years
# 0  1000001   0-17                          2
# 4  1000002    55+                         4+
# 9  1000005  26-35                          1

# %%
df1.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
# get index of first occurence of maximum Purchase value 

df1['Purchase'].idxmax()
# Out:
# 87440

# %%
df1['Purchase'].max()
# Out:
# 23961

# %%
df1.iloc[df1['Purchase'].idxmax()]   #whole row where max purchase occurs
# Out:
# User_ID                         1001474
# Product_ID                    P00052842
# Gender                                M
# Age                               26-35
# Occupation                            4
# City_Category                         A
# Stay_In_Current_City_Years            2
# Marital_Status                        1
# Product_Category_1                   10
# Product_Category_2                 15.0
# Product_Category_3                  0.0
# Purchase                          23961
# Name: 87440, dtype: object

# %%
# get value at 1st row and Purchase column pair

df1.loc[1, 'Purchase']
# Out:
# 15200

# %%
# get value at 1st row and 11th column pair

df1.iloc[1, 11]
# Out:
# 15200

# %%
df2 = df.copy()

# %%
# get the purchase amount with a given user_id and product_id

df2.loc[((df2['User_ID'] == 1000001) & (df2['Product_ID'] == 'P00069042')), 'Purchase']
# Out:
# 0    8370
# Name: Purchase, dtype: int64

# %%
##The where() method and masking¶
##We can select values from a Series with a boolean vector and it returns a subset of the data. To guarantee that the output has the same shape as the original data, we can use the where method in Series and DataFrame.

##We can select values from a DataFrame with a boolean criterion. It also preserves input data shape.

#The below code is equivalent to

#df2[df2==0]

#It replaces values with NaN where the condition is false.

df2_where=df2.where(df2 == 0)
(df2_where).head(10)
# Out:
#    User_ID Product_ID Gender  Age  Occupation City_Category  \
# 0      NaN        NaN    NaN  NaN         NaN           NaN
# 1      NaN        NaN    NaN  NaN         NaN           NaN
# 2      NaN        NaN    NaN  NaN         NaN           NaN
# 3      NaN        NaN    NaN  NaN         NaN           NaN
# 4      NaN        NaN    NaN  NaN         NaN           NaN
# 5      NaN        NaN    NaN  NaN         NaN           NaN
# 6      NaN        NaN    NaN  NaN         NaN           NaN
# 7      NaN        NaN    NaN  NaN         NaN           NaN
# 8      NaN        NaN    NaN  NaN         NaN           NaN
# 9      NaN        NaN    NaN  NaN         NaN           NaN
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                        NaN             0.0                 NaN
# 1                        NaN             0.0                 NaN
# 2                        NaN             0.0                 NaN
# 3                        NaN             0.0                 NaN
# 4                        NaN             0.0                 NaN
# 5                        NaN             0.0                 NaN
# 6                        NaN             NaN                 NaN
# 7                        NaN             NaN                 NaN
# 8                        NaN             NaN                 NaN
# 9                        NaN             NaN                 NaN
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 0.0                 0.0       NaN
# 1                 NaN                 NaN       NaN
# 2                 0.0                 0.0       NaN
# 3                 NaN                 0.0       NaN
# 4                 0.0                 0.0       NaN
# 5                 NaN                 0.0       NaN
# 6                 NaN                 NaN       NaN
# 7                 NaN                 0.0       NaN
# 8                 NaN                 0.0       NaN
# 9                 0.0                 0.0       NaN

# %%
#There is a query() method in the DataFrame objects that allows selection using an expression. 
#This method queries the columns of a DataFrame with a boolean.

df2.query('(Product_Category_1 > Product_Category_2) or (Product_Category_2 < Product_Category_3)')
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# 6       1000004  P00184942      M  46-50           7             B
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# 4                              4+               0                   8
# 6                               2               1                   1
# ...                           ...             ...                 ...
# 550063                          1               1                  20
# 550064                          3               0                  20
# 550065                         4+               1                  20
# 550066                          2               0                  20
# 550067                         4+               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      0.0                 0.0      8370
# 1                      6.0                14.0     15200
# 2                      0.0                 0.0      1422
# 4                      0.0                 0.0      7969
# 6                      8.0                17.0     19215
# ...                    ...                 ...       ...
# 550063                 0.0                 0.0       368
# 550064                 0.0                 0.0       371
# 550065                 0.0                 0.0       137
# 550066                 0.0                 0.0       365
# 550067                 0.0                 0.0       490
#
# [340459 rows x 12 columns]

# %%
df2[10:500].query('(Product_Category_1 > Product_Category_2)')
# Out:
#      User_ID Product_ID Gender    Age  Occupation City_Category  \
# 11   1000005  P00014542      M  26-35          20             A
# 12   1000005  P00031342      M  26-35          20             A
# 21   1000008  P00156442      M  26-35          12             C
# 22   1000008  P00213742      M  26-35          12             C
# 23   1000008  P00214442      M  26-35          12             C
# ..       ...        ...    ...    ...         ...           ...
# 488  1000090  P00214342      M    55+          13             C
# 490  1000090  P00001942      M    55+          13             C
# 493  1000091  P00278642      M  36-45           7             C
# 498  1000092  P00370242      F  18-25           4             B
# 499  1000092  P00340642      F  18-25           4             B
#
#     Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 11                           1               1                   8
# 12                           1               1                   8
# 21                          4+               1                   8
# 22                          4+               1                   8
# 23                          4+               1                   8
# ..                         ...             ...                 ...
# 488                          1               0                   5
# 490                          1               0                   5
# 493                          3               1                   5
# 498                          1               0                   5
# 499                          1               0                   5
#
#      Product_Category_2  Product_Category_3  Purchase
# 11                  0.0                 0.0      3957
# 12                  0.0                 0.0      6073
# 21                  0.0                 0.0      9872
# 22                  0.0                 0.0      9743
# 23                  0.0                 0.0      5982
# ..                  ...                 ...       ...
# 488                 0.0                 0.0      2010
# 490                 0.0                 0.0      7178
# 493                 0.0                 0.0      5252
# 498                 0.0                 0.0      3545
# 499                 0.0                 0.0      1868
#
# [148 rows x 12 columns]

# %%
df2.sort_values(by=['Product_Category_1'])
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 271814  1005880  P00016042      M  26-35           1             A
# 208659  1002109  P00298942      M  26-35          16             B
# 436707  1001231  P00334242      M  26-35          12             C
# 108508  1004685  P00025442      M  36-45           1             B
# 208658  1002109  P00062842      M  26-35          16             B
# ...         ...        ...    ...    ...         ...           ...
# 547638  1002549  P00375436      M    55+          13             C
# 547640  1002553  P00375436      M  26-35           7             C
# 547642  1002556  P00371644      M  26-35           4             C
# 547644  1002558  P00375436      M    55+          17             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 271814                          1               1                   1
# 208659                          2               0                   1
# 436707                          1               0                   1
# 108508                          2               1                   1
# 208658                          2               0                   1
# ...                           ...             ...                 ...
# 547638                          3               1                  20
# 547640                          0               0                  20
# 547642                          2               0                  20
# 547644                          3               1                  20
# 550067                         4+               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 271814                16.0                 0.0      8322
# 208659                 5.0                 0.0      7823
# 436707                 8.0                 0.0     15803
# 108508                 2.0                 9.0     15647
# 208658                 2.0                13.0     11643
# ...                    ...                 ...       ...
# 547638                 0.0                 0.0       613
# 547640                 0.0                 0.0       240
# 547642                 0.0                 0.0       120
# 547644                 0.0                 0.0       373
# 550067                 0.0                 0.0       490
#
# [550068 rows x 12 columns]

# %%
df2.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       550068.000000       550068.000000  550068.000000
# mean             6.735436            3.841941    9263.968713
# std              6.215492            6.250712    5023.065394
# min              0.000000            0.000000      12.000000
# 25%              0.000000            0.000000    5823.000000
# 50%              5.000000            0.000000    8047.000000
# 75%             14.000000            8.000000   12054.000000
# max             18.000000           18.000000   23961.000000

# %%
df2.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %% [markdown]
# # PLOTTING

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df2.groupby('Product_ID')['Purchase'].sum().sort_values(ascending=False).head(10).plot(kind='bar')
plt.title('Top 10 Products by Total Purchase')
plt.show()
